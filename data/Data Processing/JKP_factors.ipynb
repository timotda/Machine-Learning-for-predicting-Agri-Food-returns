# %%
# Import libraries
import pandas as pd

# %%
# Load data to a DataFrame
data = pd.read_csv('JKP_factors_data.csv')
display(data)
# Out:
#        location              name     freq weighting  direction  n_stocks  \
# 0           usa               age  monthly    vw_cap         -1       502
# 1           usa               age  monthly    vw_cap         -1       505
# 2           usa               age  monthly    vw_cap         -1       510
# 3           usa               age  monthly    vw_cap         -1       512
# 4           usa               age  monthly    vw_cap         -1       503
# ...         ...               ...      ...       ...        ...       ...
# 144615      usa  zero_trades_252d  monthly    vw_cap          1      3627
# 144616      usa  zero_trades_252d  monthly    vw_cap          1      3631
# 144617      usa  zero_trades_252d  monthly    vw_cap          1      3614
# 144618      usa  zero_trades_252d  monthly    vw_cap          1      3595
# 144619      usa  zero_trades_252d  monthly    vw_cap          1      3581
#
#         n_stocks_min        date       ret
# 0                  8  1926-03-31 -0.086738
# 1                 12  1926-04-30 -0.000572
# 2                 17  1926-05-31 -0.006332
# 3                 21  1926-06-30 -0.003012
# 4                 23  1926-07-31  0.003211
# ...              ...         ...       ...
# 144615          1622  2024-08-31  0.031409
# 144616          1630  2024-09-30 -0.011177
# 144617          1634  2024-10-31 -0.008210
# 144618          1650  2024-11-30 -0.052747
# 144619          1677  2024-12-31 -0.009848
#
# [144620 rows x 9 columns]

# %%
# Filter data for only after January 1, 2000
data['date'] = pd.to_datetime(data['date'])
data = data[data['date'] >= '2000-01-01'].reset_index(drop=True)

# Select only relevant columns
df_jkp_factors = data[['date', 'name', 'ret']]

# Rename columns for consistency
columns_names = {'name':'JKP_factor', 'date':'Date', 'ret':'Factor_return'}
df_jkp_factors = df_jkp_factors.rename(columns=columns_names)

# Format all dates to the end of month
df_jkp_factors['Date'] = df_jkp_factors['Date'] + pd.offsets.MonthEnd(0)

df_jkp_factors
# Out:
#             Date        JKP_factor  Factor_return
# 0     2000-01-31               age       0.030254
# 1     2000-02-29               age       0.259166
# 2     2000-03-31               age      -0.211559
# 3     2000-04-30               age      -0.225892
# 4     2000-05-31               age      -0.136842
# ...          ...               ...            ...
# 45895 2024-08-31  zero_trades_252d       0.031409
# 45896 2024-09-30  zero_trades_252d      -0.011177
# 45897 2024-10-31  zero_trades_252d      -0.008210
# 45898 2024-11-30  zero_trades_252d      -0.052747
# 45899 2024-12-31  zero_trades_252d      -0.009848
#
# [45900 rows x 3 columns]

# %%
# Look for number of missing values per column
df_jkp_factors.isna().sum()
# Out:
# Date             0
# JKP_factor       0
# Factor_return    0
# dtype: int64

# %%
# Pivot the DataFrame into wide format
df_jkp_factors_wide = df_jkp_factors.pivot(index='Date', columns='JKP_factor', values='Factor_return').reset_index()
df_jkp_factors_wide
# Out:
# JKP_factor       Date       age   aliq_at  aliq_mat  ami_126d     at_be  \
# 0          2000-01-31  0.030254 -0.015875  0.018536  0.058705  0.048212
# 1          2000-02-29  0.259166 -0.222644  0.138305  0.126145  0.302350
# 2          2000-03-31 -0.211559  0.113484 -0.059384 -0.097385 -0.161972
# 3          2000-04-30 -0.225892  0.130952 -0.035645 -0.057125 -0.124413
# 4          2000-05-31 -0.136842  0.138348 -0.028966 -0.031415 -0.114599
# ..                ...       ...       ...       ...       ...       ...
# 295        2024-08-31 -0.009159  0.010798  0.018197 -0.035742 -0.027581
# 296        2024-09-30  0.015388  0.005373  0.007651 -0.009591 -0.007449
# 297        2024-10-31  0.030176 -0.017033 -0.009476  0.002699 -0.020468
# 298        2024-11-30  0.055421 -0.058225 -0.021419  0.017654 -0.017568
# 299        2024-12-31  0.007252 -0.006475  0.011345 -0.000275  0.003651
#
# JKP_factor    at_gr1     at_me  at_turnover   be_gr1a  ...  taccruals_at  \
# 0           0.008562 -0.046928    -0.040382  0.011158  ...     -0.001340
# 1          -0.107640 -0.347456    -0.003528 -0.120481  ...      0.031784
# 2           0.060418  0.241058     0.068863  0.021303  ...     -0.054041
# 3           0.092468  0.199574     0.070121  0.057028  ...     -0.059227
# 4           0.114336  0.151526    -0.020165  0.102710  ...     -0.009222
# ..               ...       ...          ...       ...  ...           ...
# 295        -0.009432 -0.012035    -0.008847  0.004118  ...     -0.001930
# 296         0.003045 -0.009871     0.003660  0.008696  ...      0.010853
# 297        -0.015150  0.006831    -0.030677  0.002992  ...     -0.003090
# 298        -0.029310  0.003207    -0.008216 -0.014642  ...      0.011638
# 299         0.006723 -0.008750    -0.002555  0.003847  ...      0.005474
#
# JKP_factor  taccruals_ni  tangibility  tax_gr1a  turnover_126d  \
# 0              -0.023067     0.048493 -0.020490      -0.007638
# 1              -0.061379     0.181442  0.054843      -0.267259
# 2               0.016980    -0.093263 -0.009733       0.132038
# 3              -0.005137    -0.077151 -0.018708       0.132768
# 4               0.031111    -0.049643 -0.026389       0.112625
# ..                   ...          ...       ...            ...
# 295             0.005331    -0.027875  0.028630       0.028526
# 296             0.011034    -0.003835  0.016282      -0.009747
# 297             0.006834     0.007804  0.025230      -0.007247
# 298             0.013911     0.015177  0.020192      -0.056217
# 299             0.001703     0.001851  0.005898      -0.008834
#
# JKP_factor  turnover_var_126d   z_score  zero_trades_126d  zero_trades_21d  \
# 0                   -0.031576  0.016389         -0.006343        -0.002099
# 1                   -0.098292  0.227692         -0.258749        -0.261256
# 2                    0.150523 -0.126733          0.126554         0.115848
# 3                    0.098770 -0.103011          0.128177         0.100690
# 4                    0.054487 -0.105252          0.110061         0.080989
# ..                        ...       ...               ...              ...
# 295                 -0.004074  0.000093          0.028476         0.030556
# 296                  0.005741 -0.006687         -0.009855        -0.015172
# 297                 -0.012540 -0.015458         -0.007306        -0.001944
# 298                 -0.023397  0.001817         -0.056044        -0.046449
# 299                 -0.015877 -0.003414         -0.008837        -0.007405
#
# JKP_factor  zero_trades_252d
# 0                  -0.000643
# 1                  -0.233215
# 2                   0.094000
# 3                   0.123308
# 4                   0.103525
# ..                       ...
# 295                 0.031409
# 296                -0.011177
# 297                -0.008210
# 298                -0.052747
# 299                -0.009848
#
# [300 rows x 154 columns]

# %%
# Rename factors based on the documentation provided by Jensen, Kelly, and Pedersen
chars = pd.read_excel('https://github.com/bkelly-lab/ReplicationCrisis/raw/master/GlobalFactors/Factor%20Details.xlsx')
var_new_name = chars[["abr_jkp","name_new"]].set_index("abr_jkp").to_dict()["name_new"] # create a dictionary with the factors name as keys and the new names as values
df_jkp_factors_wide_new_name = df_jkp_factors_wide.rename(columns=var_new_name)
df_jkp_factors_wide_new_name
# Out:
# JKP_factor       Date  Firm age  Liquidity of book assets  \
# 0          2000-01-31  0.030254                 -0.015875
# 1          2000-02-29  0.259166                 -0.222644
# 2          2000-03-31 -0.211559                  0.113484
# 3          2000-04-30 -0.225892                  0.130952
# 4          2000-05-31 -0.136842                  0.138348
# ..                ...       ...                       ...
# 295        2024-08-31 -0.009159                  0.010798
# 296        2024-09-30  0.015388                  0.005373
# 297        2024-10-31  0.030176                 -0.017033
# 298        2024-11-30  0.055421                 -0.058225
# 299        2024-12-31  0.007252                 -0.006475
#
# JKP_factor  Liquidity of market assets  Amihud Measure  Book leverage  \
# 0                             0.018536        0.058705       0.048212
# 1                             0.138305        0.126145       0.302350
# 2                            -0.059384       -0.097385      -0.161972
# 3                            -0.035645       -0.057125      -0.124413
# 4                            -0.028966       -0.031415      -0.114599
# ..                                 ...             ...            ...
# 295                           0.018197       -0.035742      -0.027581
# 296                           0.007651       -0.009591      -0.007449
# 297                          -0.009476        0.002699      -0.020468
# 298                          -0.021419        0.017654      -0.017568
# 299                           0.011345       -0.000275       0.003651
#
# JKP_factor  Asset Growth  Assets-to-market  Capital turnover  \
# 0               0.008562         -0.046928         -0.040382
# 1              -0.107640         -0.347456         -0.003528
# 2               0.060418          0.241058          0.068863
# 3               0.092468          0.199574          0.070121
# 4               0.114336          0.151526         -0.020165
# ..                   ...               ...               ...
# 295            -0.009432         -0.012035         -0.008847
# 296             0.003045         -0.009871          0.003660
# 297            -0.015150          0.006831         -0.030677
# 298            -0.029310          0.003207         -0.008216
# 299             0.006723         -0.008750         -0.002555
#
# JKP_factor  Change in common equity  ...  Total accruals  \
# 0                          0.011158  ...       -0.001340
# 1                         -0.120481  ...        0.031784
# 2                          0.021303  ...       -0.054041
# 3                          0.057028  ...       -0.059227
# 4                          0.102710  ...       -0.009222
# ..                              ...  ...             ...
# 295                        0.004118  ...       -0.001930
# 296                        0.008696  ...        0.010853
# 297                        0.002992  ...       -0.003090
# 298                       -0.014642  ...        0.011638
# 299                        0.003847  ...        0.005474
#
# JKP_factor  Percent total accruals  Asset tangibility  Tax expense surprise  \
# 0                        -0.023067           0.048493             -0.020490
# 1                        -0.061379           0.181442              0.054843
# 2                         0.016980          -0.093263             -0.009733
# 3                        -0.005137          -0.077151             -0.018708
# 4                         0.031111          -0.049643             -0.026389
# ..                             ...                ...                   ...
# 295                       0.005331          -0.027875              0.028630
# 296                       0.011034          -0.003835              0.016282
# 297                       0.006834           0.007804              0.025230
# 298                       0.013911           0.015177              0.020192
# 299                       0.001703           0.001851              0.005898
#
# JKP_factor  Share turnover  Coefficient of variation for share turnover  \
# 0                -0.007638                                    -0.031576
# 1                -0.267259                                    -0.098292
# 2                 0.132038                                     0.150523
# 3                 0.132768                                     0.098770
# 4                 0.112625                                     0.054487
# ..                     ...                                          ...
# 295               0.028526                                    -0.004074
# 296              -0.009747                                     0.005741
# 297              -0.007247                                    -0.012540
# 298              -0.056217                                    -0.023397
# 299              -0.008834                                    -0.015877
#
# JKP_factor  Altman Z-score  \
# 0                 0.016389
# 1                 0.227692
# 2                -0.126733
# 3                -0.103011
# 4                -0.105252
# ..                     ...
# 295               0.000093
# 296              -0.006687
# 297              -0.015458
# 298               0.001817
# 299              -0.003414
#
# JKP_factor  Number of zero trades with turnover as tiebreaker (6 months)  \
# 0                                                   -0.006343
# 1                                                   -0.258749
# 2                                                    0.126554
# 3                                                    0.128177
# 4                                                    0.110061
# ..                                                        ...
# 295                                                  0.028476
# 296                                                 -0.009855
# 297                                                 -0.007306
# 298                                                 -0.056044
# 299                                                 -0.008837
#
# JKP_factor  Number of zero trades with turnover as tiebreaker (1 month)  \
# 0                                                   -0.002099
# 1                                                   -0.261256
# 2                                                    0.115848
# 3                                                    0.100690
# 4                                                    0.080989
# ..                                                        ...
# 295                                                  0.030556
# 296                                                 -0.015172
# 297                                                 -0.001944
# 298                                                 -0.046449
# 299                                                 -0.007405
#
# JKP_factor  Number of zero trades with turnover as tiebreaker (12 months)
# 0                                                   -0.000643
# 1                                                   -0.233215
# 2                                                    0.094000
# 3                                                    0.123308
# 4                                                    0.103525
# ..                                                        ...
# 295                                                  0.031409
# 296                                                 -0.011177
# 297                                                 -0.008210
# 298                                                 -0.052747
# 299                                                 -0.009848
#
# [300 rows x 154 columns]

# %% [markdown]
# # Handling outliers

# %%
# Factors names into a list
factors = list(df_jkp_factors_wide_new_name.columns[1:])
factors
# Out:
# ['Firm age',
#  'Liquidity of book assets',
#  'Liquidity of market assets',
#  'Amihud Measure',
#  'Book leverage',
#  'Asset Growth',
#  'Assets-to-market',
#  'Capital turnover',
#  'Change in common equity',
#  'Book-to-market equity',
#  'Market Beta',
#  'Dimson beta',
#  'Frazzini-Pedersen market beta',
#  'Downside beta',
#  'Book-to-market enterprise value',
#  'The high-low bid-ask spread',
#  'Abnormal corporate investment',
#  'CAPEX growth (1 year)',
#  'CAPEX growth (2 years)',
#  'CAPEX growth (3 years)',
#  'Cash-to-assets',
#  'Net stock issues',
#  'Change in current operating assets',
#  'Change in current operating liabilities',
#  'Cash-based operating profits-to-book assets',
#  'Cash-based operating profits-to-lagged book assets',
#  'Market correlation',
#  'Coskewness',
#  'Change in current operating working capital',
#  'Net debt issuance',
#  'Growth in book debt (3 years)',
#  'Debt-to-market',
#  'Change gross margin minus change sales',
#  'Dividend yield',
#  'Dollar trading volume',
#  'Coefficient of variation for dollar trading volume',
#  'Change sales minus change Inventory',
#  'Change sales minus change receivables',
#  'Change sales minus change SG&A',
#  'Earnings variability',
#  'Return on net operating assets',
#  'Profit margin',
#  'Ebitda-to-market enterprise value',
#  'Hiring rate',
#  'Equity duration',
#  'Net equity issuance',
#  'Equity net payout',
#  'Net payout yield',
#  'Payout yield',
#  'Pitroski F-score',
#  'Free cash flow-to-price',
#  'Change in financial liabilities',
#  'Gross profits-to-assets',
#  'Gross profits-to-lagged assets',
#  'Inventory growth',
#  'Inventory change',
#  'Idiosyncratic skewness from the CAPM',
#  'Idiosyncratic skewness from the Fama-French 3-factor model',
#  'Idiosyncratic skewness from the q-factor model',
#  'Intrinsic value-to-market',
#  'Idiosyncratic volatility from the CAPM (21 days)',
#  'Idiosyncratic volatility from the CAPM (252 days)',
#  'Idiosyncratic volatility from the Fama-French 3-factor model',
#  'Idiosyncratic volatility from the q-factor model',
#  'Kaplan-Zingales index',
#  'Change in long-term net operating assets',
#  'Change in long-term investments',
#  'Market Equity',
#  'Mispricing factor: Management',
#  'Mispricing factor: Performance',
#  'Change in noncurrent operating assets',
#  'Change in noncurrent operating liabilities',
#  'Net debt-to-price',
#  'Net total issuance',
#  'Change in net financial assets',
#  'Earnings persistence',
#  'Return on equity',
#  'Number of consecutive quarters with earnings increases',
#  'Earnings volatility',
#  'Earnings-to-price',
#  'Quarterly return on assets',
#  'Change in quarterly return on assets',
#  'Quarterly return on equity',
#  'Change in quarterly return on equity',
#  'Standardized earnings surprise',
#  'Change in net noncurrent operating assets',
#  'Net operating assets',
#  'Change in net operating assets',
#  'Ohlson O-score',
#  'Operating accruals',
#  'Percent operating accruals',
#  'Operating cash flow to assets',
#  'Change in operating cash flow to assets',
#  'Operating cash flow-to-market',
#  'Cash flow volatility',
#  'Operating profits-to-book assets',
#  'Operating profits-to-lagged book assets',
#  'Operating profits-to-book equity',
#  'Operating profits-to-lagged book equity',
#  'Operating leverage',
#  'Taxable income-to-book income',
#  'Change PPE and Inventory',
#  'Price per share',
#  'Current price to high price over last year',
#  'Quality minus Junk: Composite',
#  'Quality minus Junk: Growth',
#  'Quality minus Junk: Profitability',
#  'Quality minus Junk: Safety',
#  'R&D capital-to-book assets',
#  'R&D-to-market',
#  'R&D-to-sales',
#  'Residual momentum t-12 to t-1',
#  'Residual momentum t-6 to t-1',
#  'Price momentum t-12 to t-1',
#  'Price momentum t-12 to t-7',
#  'Short-term reversal',
#  'Price momentum t-3 to t-1',
#  'Long-term reversal',
#  'Price momentum t-6 to t-1',
#  'Price momentum t-9 to t-1',
#  'Maximum daily return',
#  'Highest 5 days of return',
#  'Highest 5 days of return scaled by volatility',
#  'Total skewness',
#  'Return volatility',
#  'Asset turnover',
#  'Labor force efficiency',
#  'Sales Growth (1 year)',
#  'Sales Growth (3 years)',
#  'Sales-to-market',
#  'Sales growth (1 quarter)',
#  'Standardized Revenue surprise',
#  'Years 11-15 lagged returns, annual',
#  'Years 11-15 lagged returns, nonannual',
#  'Years 16-20 lagged returns, annual',
#  'Years 16-20 lagged returns, nonannual',
#  'Year 1-lagged return, annual',
#  'Year 1-lagged return, nonannual',
#  'Years 2-5 lagged returns, annual',
#  'Years 2-5 lagged returns, nonannual',
#  'Years 6-10 lagged returns, annual',
#  'Years 6-10 lagged returns, nonannual',
#  'Change in short-term investments',
#  'Total accruals',
#  'Percent total accruals',
#  'Asset tangibility',
#  'Tax expense surprise',
#  'Share turnover',
#  'Coefficient of variation for share turnover',
#  'Altman Z-score',
#  'Number of zero trades with turnover as tiebreaker (6 months)',
#  'Number of zero trades with turnover as tiebreaker (1 month)',
#  'Number of zero trades with turnover as tiebreaker (12 months)']

# %% [markdown]
# Z-scores ($z = \frac{x_i - \mu}{\sigma}$) are often used to detect outliers in datasets. Observations with a z-score less than -3 or greater than 3 are often deemed to be outliers.

# %%
# Compute z-scores
z_scores = (df_jkp_factors_wide_new_name[factors] - df_jkp_factors_wide_new_name[factors].mean()) / df_jkp_factors_wide_new_name[factors].std()

# Select the biggest outlier per column
outlier_columns = z_scores.abs().max()

# Select the first 20 columns with the biggest outlier
biggest_outliers = outlier_columns.sort_values(ascending=False).head(20)
biggest_outliers
# Out:
# JKP_factor
# R&D capital-to-book assets                                     8.202260
# Change in noncurrent operating liabilities                     7.964524
# Book leverage                                                  7.581838
# Coefficient of variation for dollar trading volume             7.564661
# Net debt-to-price                                              7.175027
# Price momentum t-3 to t-1                                      7.174680
# Debt-to-market                                                 7.095864
# Book-to-market enterprise value                                7.089557
# Equity duration                                                7.071814
# Assets-to-market                                               7.032712
# Asset tangibility                                              7.005187
# Book-to-market equity                                          6.994425
# Cash flow volatility                                           6.966034
# Ebitda-to-market enterprise value                              6.939787
# Year 1-lagged return, nonannual                                6.933166
# Idiosyncratic skewness from the Fama-French 3-factor model     6.838095
# Idiosyncratic skewness from the q-factor model                 6.814405
# Number of zero trades with turnover as tiebreaker (1 month)    6.793524
# R&D-to-sales                                                   6.739127
# Sales-to-market                                                6.722494
# dtype: float64

# %%
# Drop all columns for which its biggest outlier has a z-score greater or equal to 7
columns_to_drop = outlier_columns[outlier_columns >= 7].index
df_jkp_factors_wide_new_name_out = df_jkp_factors_wide_new_name.drop(columns=columns_to_drop)

# Update factors list
factors_updated = [col for col in factors if col not in columns_to_drop]

# Print the shape of the DataFrame to know how many columns were dropped (154-143=11)
df_jkp_factors_wide_new_name_out.shape
# Out:
# (300, 143)

# %%
# Compute z-scores
z_scores = (df_jkp_factors_wide_new_name_out[factors_updated] - df_jkp_factors_wide_new_name_out[factors_updated].mean()) / df_jkp_factors_wide_new_name_out[factors_updated].std()

# Compute the number of outliers per column
outliers_count = (z_scores.abs() > 3).sum()

# Select the 20 columns with the most outliers
outliers_count.sort_values(ascending=False).head(20)
# Out:
# JKP_factor
# Change in quarterly return on equity    9
# Change in quarterly return on assets    8
# Sales-to-market                         8
# CAPEX growth (2 years)                  8
# Net payout yield                        8
# Return volatility                       8
# Net equity issuance                     8
# Sales growth (1 quarter)                8
# Liquidity of book assets                8
# Asset Growth                            8
# Return on net operating assets          8
# Altman Z-score                          8
# Hiring rate                             7
# Operating profits-to-book equity        7
# Payout yield                            7
# Operating cash flow-to-market           7
# Earnings-to-price                       7
# Ohlson O-score                          7
# Operating cash flow to assets           7
# Price momentum t-6 to t-1               7
# dtype: int64

# %%
# Drop all columns that have more than or 8 outliers
columns_to_drop_ = outliers_count[outliers_count >= 8].index
df_jkp_factors_wide_new_name_outliers = df_jkp_factors_wide_new_name_out.drop(columns=columns_to_drop_)

# Update factors list
factors = [col for col in factors if col not in columns_to_drop_]

# Print the shape of the DataFrame to know how many columns were dropped (143-131=12)
df_jkp_factors_wide_new_name_outliers.shape
# Out:
# (300, 131)

# %% [markdown]
# 23 columns were dropped in total.

# %%
# Save the clean DataFrame to a csv file
df_jkp_factors_wide_new_name_outliers.to_csv('df_jkp_factors.csv', index=False)
